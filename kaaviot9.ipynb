# %%
from datetime import datetime
print(f'Päivitetty {datetime.now()}')
# Out:
# Päivitetty 2021-08-15 11:48:17.296741

# %%
import pandas as pd
import matplotlib.pyplot as plt

#valmiin tyylimäärittelyn käyttöönotto
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# <h2>Aikasarjojen vertailu</h2>

# %%
#luon dataframen
df = pd.DataFrame({'Etelä':[120,130,167,210,130,135,172,213,134],
                'Keski':[98,102,120,180,103,109,140,189,104],
                'Pohjoinen':[89,95,108,120,88,99,110,123,88]},
                index=['1.2009','2.2009','3.2009','4.2009','1.2010','2.2010','3.2010','4.2010','1.2011'])
df
# Out:
#         Etelä  Keski  Pohjoinen
# 1.2009    120     98         89
# 2.2009    130    102         95
# 3.2009    167    120        108
# 4.2009    210    180        120
# 1.2010    130    103         88
# 2.2010    135    109         99
# 3.2010    172    140        110
# 4.2010    213    189        123
# 1.2011    134    104         88

# %% [markdown]
# Huomaa, miten indeksin arvot tulevat vaaka-akselille.
#
# Lisäparametri <b>style</b> määrittää viivan ja havaintopisteiden tyylin. Lisätietoa: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html

# %%
df.plot(style='-o', rot=45)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Pylväskaavio ei ole havainnollinen aikasarjojen vertailussa (vertaa viivakaavioon)!

# %%
df.plot.bar(rot=45)
# Out:
# <AxesSubplot:>
